# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("Automobile - Govindaraj V.csv")

# %%
data
# Out:
#      symboling  normalized_losses         make  ... city_mpg highway_mpg  price
# 0            3                168  alfa-romero  ...       21          27  13495
# 1            3                168  alfa-romero  ...       21          27  16500
# 2            1                168  alfa-romero  ...       19          26  16500
# 3            2                164         audi  ...       24          30  13950
# 4            2                164         audi  ...       18          22  17450
# ..         ...                ...          ...  ...      ...         ...    ...
# 196         -1                 95        volvo  ...       23          28  16845
# 197         -1                 95        volvo  ...       19          25  19045
# 198         -1                 95        volvo  ...       18          23  21485
# 199         -1                 95        volvo  ...       26          27  22470
# 200         -1                 95        volvo  ...       19          25  22625
#
# [201 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
#  15  number_of_cylinders  201 non-null    object
#  16  engine_size          201 non-null    int64
#  17  fuel_system          201 non-null    object
#  18  bore                 201 non-null    float64
#  19  stroke               201 non-null    float64
#  20  compression_ratio    201 non-null    float64
#  21  horsepower           201 non-null    int64
#  22  peak_rpm             201 non-null    int64
#  23  city_mpg             201 non-null    int64
#  24  highway_mpg          201 non-null    int64
#  25  price                201 non-null    int64
# dtypes: float64(7), int64(9), object(10)
# memory usage: 41.0+ KB

# %%
data.shape
# Out:
# (201, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
#  15  number_of_cylinders  201 non-null    object
#  16  engine_size          201 non-null    int64
#  17  fuel_system          201 non-null    object
#  18  bore                 201 non-null    float64
#  19  stroke               201 non-null    float64
#  20  compression_ratio    201 non-null    float64
#  21  horsepower           201 non-null    int64
#  22  peak_rpm             201 non-null    int64
#  23  city_mpg             201 non-null    int64
#  24  highway_mpg          201 non-null    int64
#  25  price                201 non-null    int64
# dtypes: float64(7), int64(9), object(10)
# memory usage: 41.0+ KB

# %%
data.head()
# Out:
#    symboling  normalized_losses         make  ... city_mpg highway_mpg  price
# 0          3                168  alfa-romero  ...       21          27  13495
# 1          3                168  alfa-romero  ...       21          27  16500
# 2          1                168  alfa-romero  ...       19          26  16500
# 3          2                164         audi  ...       24          30  13950
# 4          2                164         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %%
data.tail()
# Out:
#      symboling  normalized_losses   make  ... city_mpg highway_mpg  price
# 196         -1                 95  volvo  ...       23          28  16845
# 197         -1                 95  volvo  ...       19          25  19045
# 198         -1                 95  volvo  ...       18          23  21485
# 199         -1                 95  volvo  ...       26          27  22470
# 200         -1                 95  volvo  ...       19          25  22625
#
# [5 rows x 26 columns]

# %%
data.dtypes
# Out:
# symboling                int64
# normalized_losses        int64
# make                    object
# fuel_type               object
# aspiration              object
# number_of_doors         object
# body_style              object
# drive_wheels            object
# engine_location         object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# number_of_cylinders     object
# engine_size              int64
# fuel_system             object
# bore                   float64
# stroke                 float64
# compression_ratio      float64
# horsepower               int64
# peak_rpm                 int64
# city_mpg                 int64
# highway_mpg              int64
# price                    int64
# dtype: object

# %%
data.hist(figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f98dbf779e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98dc02d668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d98ec860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98dbe21b38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f98d9939278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d9087278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8fae6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8f608d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8f60940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8ec8dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8e8c080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8ebc2e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8e73550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8e247b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8dd8a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8d8dc88>]],
#       dtype=object)

# %%
data.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
data.describe()
# Out:
#         symboling  normalized_losses  ...  highway_mpg         price
# count  201.000000         201.000000  ...   201.000000    201.000000
# mean     0.840796         125.189055  ...    30.686567  13207.129353
# std      1.254802          33.572966  ...     6.815150   7947.066342
# min     -2.000000          65.000000  ...    16.000000   5118.000000
# 25%      0.000000         101.000000  ...    25.000000   7775.000000
# 50%      1.000000         122.000000  ...    30.000000  10295.000000
# 75%      2.000000         150.000000  ...    34.000000  16500.000000
# max      3.000000         256.000000  ...    54.000000  45400.000000
#
# [8 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
#  15  number_of_cylinders  201 non-null    object
#  16  engine_size          201 non-null    int64
#  17  fuel_system          201 non-null    object
#  18  bore                 201 non-null    float64
#  19  stroke               201 non-null    float64
#  20  compression_ratio    201 non-null    float64
#  21  horsepower           201 non-null    int64
#  22  peak_rpm             201 non-null    int64
#  23  city_mpg             201 non-null    int64
#  24  highway_mpg          201 non-null    int64
#  25  price                201 non-null    int64
# dtypes: float64(7), int64(9), object(10)
# memory usage: 41.0+ KB

# %%
#byevirte analysus
#we wil be some co reeelation method and all

# %%
data.corr()
# Out:
#                    symboling  normalized_losses  ...  highway_mpg     price
# symboling           1.000000           0.474993  ...     0.036233 -0.082391
# normalized_losses   0.474993           1.000000  ...    -0.264594  0.208886
# wheel_base         -0.535987           0.007815  ...    -0.543304  0.584642
# length             -0.365404           0.103659  ...    -0.698142  0.690628
# width              -0.242423           0.153752  ...    -0.680635  0.751265
# height             -0.550160          -0.335476  ...    -0.104812  0.135486
# curb_weight        -0.233118           0.178547  ...    -0.794889  0.834415
# engine_size        -0.110581           0.174788  ...    -0.679571  0.872335
# bore               -0.146355           0.007498  ...    -0.586917  0.543052
# stroke              0.018373           0.062666  ...    -0.051793  0.081434
# compression_ratio  -0.182196          -0.120846  ...     0.268465  0.071107
# horsepower          0.075287           0.276665  ...    -0.804241  0.810795
# peak_rpm            0.279849           0.211812  ...    -0.058054 -0.104846
# city_mpg           -0.035527          -0.301206  ...     0.972044 -0.686571
# highway_mpg         0.036233          -0.264594  ...     1.000000 -0.704692
# price              -0.082391           0.208886  ...    -0.704692  1.000000
#
# [16 rows x 16 columns]

# %%
x.hist(figsize=(20,25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f98dc10d048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8a1f4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d88acdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8867198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8818518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d87cb898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d87fec18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d87b0f60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f98d87b0fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d87216d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d86d0a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98dc1be9e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8fb9a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8e24ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d8b60da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98d89f9ef0>]],
#       dtype=object)

# %%
sns.jointplot(data['engine_size'],data['horsepower']) #sccater ploat ad histogram
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(data['engine_size'],data['horsepower'],kind='hex')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(data['engine_size'],data['horsepower'],kind='kde')#kernl density estimation
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# PLOTING FOR CATEGORING DATA like petro and disel 
#disctre  VALUE

# %%
sns.stripplot(data['fuel_type'],data['horsepower'])#horse == continue and remaing is disctre value
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['fuel_type'].value_counts()
# Out:
# gas       181
# diesel     20
# Name: fuel_type, dtype: int64

# %%
sns.swarmplot(data['fuel_type'],data['horsepower'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #box plot
# -outlier/noise decteded in the data
# some odd man out

# %%
sns.boxplot(data['horsepower'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.boxplot(figsize=(30,40))

# %%
sns.boxplot(data['number_of_doors'],data['horsepower'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['number_of_doors'],data['horsepower'],hue=data['fuel_type'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(data['body_style'],data['horsepower'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(data['body_style'],data['horsepower'],hue=data['fuel_type'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['horsepower'].describe()
# Out:
# count    201.000000
# mean     103.263682
# std       37.389372
# min       48.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      262.000000
# Name: horsepower, dtype: float64

# %%
sns.countplot(data['body_style'],hue=data['fuel_type'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data['fuel_type'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data['number_of_cylinders'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pointplot(data['body_style'],data['horsepower'],hue=data['number_of_cylinders'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#multiple panel Categorical plots

# %%
sns.catplot(x='fuel_type',y='horsepower',col='drive_wheels',data=data,kind='box')

# %%
sns.catplot(x='fuel_type',y='horsepower',col='number_of_doors',data=data,kind='box')

# %%
sns.lmplot(x='horsepower',y='engine_size',data=data)
